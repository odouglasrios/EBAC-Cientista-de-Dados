# %% [markdown]
# # Módulo 07, Tarefa 01
#
# Vamos começar a mexer na nossa base de projeto? Já fizemos um exercício de montar a variável resposta, já pudemos perceber que essa atividade pode não ser trivial. Vamos agora trabalhar a base para que fique propícia ao *scikitlearn* para trabalharmos.
#
# Lembrando, a base se chama demo01.csv, e originalmente está publicada [aqui](https://www.kaggle.com/rikdifos/credit-card-approval-prediction).

# %%
# carregando os pacotes
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# #### 1) Carregue a base e avalie:
#
# - As variáveis
# - Tipos de dados de cada variável
# - Quantidade de missings
# - Distribuição da variável resposta (mau)

# %%
# carregando a base de dados
df = pd.read_csv("C:/Users/Dougl/Downloads/demo01.csv")

# %%
# visualizando a base de dados
df
# Out:
#       sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0        M                Y               Y           0               Working
# 1        F                N               Y           0  Commercial associate
# 2        F                N               Y           0  Commercial associate
# 3        M                Y               Y           0               Working
# 4        F                Y               N           0               Working
# ...    ...              ...             ...         ...                   ...
# 16645    F                N               Y           0               Working
# 16646    F                N               Y           0  Commercial associate
# 16647    M                Y               Y           0               Working
# 16648    M                Y               Y           0               Working
# 16649    F                N               Y           0             Pensioner
#
# ...

# %%
# visualizando as informações da base
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sexo                   16650 non-null  object
#  1   posse_de_veiculo       16650 non-null  object
#  2   posse_de_imovel        16650 non-null  object
#  3   qtd_filhos             16650 non-null  int64
#  4   tipo_renda             16650 non-null  object
#  5   educacao               16650 non-null  object
#  6   estado_civil           16650 non-null  object
#  7   tipo_residencia        16650 non-null  object
#  8   idade                  16650 non-null  float64
#  9   tempo_emprego          16650 non-null  float64
#  10  possui_celular         16650 non-null  int64
#  11  possui_fone_comercial  16650 non-null  int64
#  12  possui_fone            16650 non-null  int64
#  13  possui_email           16650 non-null  int64
# ...

# %%
# visualizando as variáveis e os seus tipos
df.dtypes
# Out:
# sexo                      object
# posse_de_veiculo          object
# posse_de_imovel           object
# qtd_filhos                 int64
# tipo_renda                object
# educacao                  object
# estado_civil              object
# tipo_residencia           object
# idade                    float64
# tempo_emprego            float64
# possui_celular             int64
# possui_fone_comercial      int64
# possui_fone                int64
# possui_email               int64
# qt_pessoas_residencia    float64
# mau                         bool
# dtype: object

# %%
# visualizando a quantidade de missing
df.isnull().sum()
# Out:
# sexo                     0
# posse_de_veiculo         0
# posse_de_imovel          0
# qtd_filhos               0
# tipo_renda               0
# educacao                 0
# estado_civil             0
# tipo_residencia          0
# idade                    0
# tempo_emprego            0
# possui_celular           0
# possui_fone_comercial    0
# possui_fone              0
# possui_email             0
# qt_pessoas_residencia    0
# mau                      0
# dtype: int64

# %%
# verificando dados duplicados
df.duplicated().sum()
# Out:
# 9880

# %%
# removendo dados duplicados
df = df.drop_duplicates()
df.shape
# Out:
# (6770, 16)

# %%
# resetando o índice
df.reset_index(drop = True, inplace = True)
df.tail()
# Out:
#      sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 6765    F                N               Y           1               Working
# 6766    F                N               Y           0               Working
# 6767    F                N               Y           0  Commercial associate
# 6768    M                Y               Y           0               Working
# 6769    F                N               Y           0             Pensioner
#
#                            educacao          estado_civil    tipo_residencia  \
# 6765  Secondary / secondary special  Single / not married  House / apartment
# 6766  Secondary / secondary special        Civil marriage  House / apartment
# 6767  Secondary / secondary special               Married  House / apartment
# 6768  Secondary / secondary special               Married  House / apartment
# 6769               Higher education               Married  House / apartment
#
# ...

# %%
# Distribuição da variável resposta (mau)
df['mau'].value_counts()
# Out:
# False    6472
# True      298
# Name: mau, dtype: int64

# %%
# calculando a frequência em percentual
round(df['mau'].value_counts(normalize=True)*100,2)
# Out:
# False    95.6
# True      4.4
# Name: mau, dtype: float64

# %% [markdown]
# #### 2) Vamos montar um metadados
#
# 1. Crie um dataframe com os nomes de cada variável e o tipo de dados de cada variável.
# 2. Adicione uma coluna nesse *dataframe* chamada "qtd_categorias" e coloque nela o número de categorias correspondente de cada variável.
#     Dica:
#         1. inicie uma lista vazia
#         2. faça um for ao longo dos nomes das variáveis,
#         3. conte o número de categorias dessa variável
#         4. acumule essa informação de 3. na lista que você criou em 1.
#         5. No final, essa lista pode ser atribuída à nossa variável.
# 3. Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}.

# %%
# 1.Crie um dataframe com os nomes de cada variável e o tipo de dados de cada variável.
df_tipo_dados = pd.DataFrame(df.dtypes, columns = ['tipo_variavel'])

df_tipo_dados
# Out:
#                       tipo_variavel
# sexo                         object
# posse_de_veiculo             object
# posse_de_imovel              object
# qtd_filhos                    int64
# tipo_renda                   object
# educacao                     object
# estado_civil                 object
# tipo_residencia              object
# idade                       float64
# tempo_emprego               float64
# possui_celular                int64
# possui_fone_comercial         int64
# possui_fone                   int64
# possui_email                  int64
# qt_pessoas_residencia       float64
# mau                            bool

# %%
# 2.Adicione uma coluna nesse dataframe chamada "qtd_categorias" 
# coloque nela o número de categorias correspondente de cada variável.

df_tipo_dados['qtd_categorias'] = 0

for i in df_tipo_dados.index:
    df_tipo_dados.loc[i, 'qtd_categorias'] = len(df.groupby([i]).size())
    
df_tipo_dados
# Out:
#                       tipo_variavel  qtd_categorias
# sexo                         object               2
# posse_de_veiculo             object               2
# posse_de_imovel              object               2
# qtd_filhos                    int64               8
# tipo_renda                   object               5
# educacao                     object               5
# estado_civil                 object               5
# tipo_residencia              object               6
# idade                       float64            5298
# tempo_emprego               float64            3005
# possui_celular                int64               1
# possui_fone_comercial         int64               2
# possui_fone                   int64               2
# possui_email                  int64               2
# qt_pessoas_residencia       float64               9
# mau                            bool               2

# %%
# Criando variáveis Dummies para as variáveis "tipo_renda", "educacao", "estado_civil", "tipo_residencia"
df_encoded = pd.get_dummies(df, columns = ["tipo_renda", "educacao", "estado_civil", "tipo_residencia"], drop_first = True)
df_encoded
# Out:
#      sexo posse_de_veiculo posse_de_imovel  qtd_filhos      idade  \
# 0       M                Y               Y           0  58.832877
# 1       F                N               Y           0  52.356164
# 2       M                Y               Y           0  46.224658
# 3       F                Y               N           0  29.230137
# 4       F                N               Y           0  27.482192
# ...   ...              ...             ...         ...        ...
# 6765    F                N               Y           1  34.857534
# 6766    F                N               Y           0  54.109589
# 6767    F                N               Y           0  43.389041
# 6768    M                Y               Y           0  30.005479
# 6769    F                N               Y           0  33.936986
#
#       tempo_emprego  possui_celular  possui_fone_comercial  possui_fone  \
# 0          3.106849               1                      0            0
# ...

# %% [markdown]
# #### 3) Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}. Crie um *dataframe* apenas com as variáveis apropriadas para entrada no scikitlearn - elimine as variáveis tipo *str*, mantendo apenas suas versões *dummy*.

# %%
# mapeando a variável 'sexo'
df_encoded['sexo'].unique()
# alterando os dados da variável 'sexo'
df_encoded['sexo'] = df_encoded.sexo.map({'F': 0, 'M': 1})

# mapeando a variável 'posse_de_veiculo'
df_encoded['posse_de_veiculo'].unique()
# alterando os dados da variável 'posse_de_veiculo'
df_encoded['posse_de_veiculo'] = df_encoded.posse_de_veiculo.map({'Y': 0, 'N': 1})

# mapeando a variável 'posse_de_imovel'
df_encoded['posse_de_imovel'].unique()
# alterando os dados da variável 'posse_de_imovel'
df_encoded['posse_de_imovel'] = df_encoded.posse_de_imovel.map({'Y': 0, 'N': 1})

# visualizando o df
df_encoded
# Out:
#       sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos      idade  \
# 0        1                 0                0           0  58.832877
# 1        0                 1                0           0  52.356164
# 2        1                 0                0           0  46.224658
# 3        0                 0                1           0  29.230137
# 4        0                 1                0           0  27.482192
# ...    ...               ...              ...         ...        ...
# 6765     0                 1                0           1  34.857534
# 6766     0                 1                0           0  54.109589
# 6767     0                 1                0           0  43.389041
# 6768     1                 0                0           0  30.005479
# 6769     0                 1                0           0  33.936986
#
#       tempo_emprego  possui_celular  possui_fone_comercial  possui_fone  \
# ...

# %% [markdown]
# #### 4) Qual variável é mais poderosa?
#
# Considere as variáveis ```possui_email``` e ```posse_de_veiculo```. Faça uma tabela cruzada entre elas e responda qual delas te parece mais poderosa para prever a probabilidade de ```mau = 1```?

# %%
tabela_email = pd.crosstab(df['possui_email'], df['mau'])
tabela_email.div(tabela_email.sum(axis=1), axis=0)
# Out:
# mau              False      True
# possui_email
# 0             0.955197  0.044803
# 1             0.964602  0.035398

# %%
tabela_veiculo = pd.crosstab(df['posse_de_veiculo'], df['mau'])
tabela_veiculo.div(tabela_veiculo.sum(axis=1), axis=0)
# Out:
# mau                  False      True
# posse_de_veiculo
# N                 0.954880  0.045120
# Y                 0.957796  0.042204

# %% [markdown]
# #### 5) Salve a base, pois ela será utilizada no final deste módulo.

# %%
df_encoded.to_csv('demo01_encoded.csv')
